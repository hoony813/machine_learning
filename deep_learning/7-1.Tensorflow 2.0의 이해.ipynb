# %% [markdown]
# # Tensorflow 2.0의 이해
#
# ## Import modules

# %%
import tensorflow as tf

# %% [markdown]
# ## 데이터 불러오기

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ## 네트워크 구조 정의

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),
                                   tf.keras.layers.Dense(128, activation='relu'),
                                    tf.keras.layers.Dropout(0.2),
                                    tf.keras.layers.Dense(10, activation='softmax')])

# %% [markdown]
# ## Keras 모델 Compile

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %% [markdown]
# ## 학습 수행

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 963us/step - loss: 0.2957 - accuracy: 0.9142
# Epoch 2/5
# 1875/1875 [==============================] - 2s 965us/step - loss: 0.1439 - accuracy: 0.9568
# Epoch 3/5
# 1875/1875 [==============================] - 2s 823us/step - loss: 0.1085 - accuracy: 0.9676
# Epoch 4/5
# 1875/1875 [==============================] - 2s 915us/step - loss: 0.0879 - accuracy: 0.9730
# Epoch 5/5
# 1875/1875 [==============================] - 2s 830us/step - loss: 0.0756 - accuracy: 0.9759

# %% [markdown]
# ## 학습 결과 테스트

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 553us/step - loss: 0.0746 - accuracy: 0.9771
# [0.07459301501512527, 0.9771000146865845]
